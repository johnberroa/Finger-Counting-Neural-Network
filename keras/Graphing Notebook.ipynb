# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # SIMPLE CNN

# %%
tacc = np.load('Training Data/Simple/t-acc.npy')
tloss = np.load('Training Data/Simple/t-loss.npy')
vacc = np.load('Training Data/Simple/v-acc.npy')
vloss = np.load('Training Data/Simple/v-loss.npy')

# %%
print("LAST T-ACC:", tacc[-1], "MAX T-ACC:", max(tacc))
print("LAST V-ACC:", vacc[-1], "MAX V-ACC:", max(vacc))
# Out:
# LAST T-ACC: 0.9913112236801859 MAX T-ACC: 0.9976303315652302
# LAST V-ACC: 0.5047393441200256 MAX V-ACC: 0.5071089863777161

# %%
fig, ax = plt.subplots(1,2, figsize=(20, 10))

# plt.suptitle("Simple CNN Performance")
plt.rc('axes', titlesize=20) 
plt.rc('axes', labelsize=20)

ax[0].plot(tacc[:200], c='b', label="Training")
ax[0].plot(vacc[:200], c='orange', label="Validation")
ax[0].axhline(.2, ls='--', c='r', label="Chance")
ax[0].set_xlabel("Training step")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Accuracy (max on val: {:.2f})".format(max(vacc)))
ax[0].legend()

ax[1].plot(tloss[:200], c='b', label="Training")
ax[1].plot(vloss[:200], c='orange', label="Validation")
ax[1].set_xlabel("Training step")
ax[1].set_ylabel("Loss")
ax[1].set_title("Loss (min on val: {:.2f})".format(min(vloss)))
ax[1].legend()

# plt.tight_layout()
plt.savefig('simple_cnn_500batch.png', bbox_inches='tight')
plt.show()

# %%
########################################################################################

# %% [markdown]
# # LARGE CNN

# %%
tlacc = np.load('Training Data/Large/tL-acc.npy')
tlloss = np.load('Training Data/Large/tL-loss.npy')
vlacc = np.load('Training Data/Large/vL-acc.npy')
vlloss = np.load('Training Data/Large/vL-loss.npy')

# %%
print("LAST T-ACC:", tlacc[-1], "MAX T-ACC:", max(tlacc))
print("LAST V-ACC:", vlacc[-1], "MAX V-ACC:", max(vlacc))
# Out:
# LAST T-ACC: 0.9877567117059777 MAX T-ACC: 0.9948657203059625
# LAST V-ACC: 0.5604265391544143 MAX V-ACC: 0.6753554505194533

# %%
fig, ax = plt.subplots(1,2, figsize=(20, 10))

# plt.suptitle("Large CNN Performance")
plt.rc('axes', titlesize=20) 
plt.rc('axes', labelsize=20)

ax[0].plot(tlacc, c='b', label="Training")
ax[0].plot(vlacc, c='orange', label="Validation")
ax[0].axhline(.2, ls='--', c='r', label="Chance")
ax[0].set_xlabel("Training step")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Accuracy (max on val: {:.2f})".format(max(vlacc)))
ax[0].legend()

ax[1].plot(tlloss, c='b', label="Training")
ax[1].plot(vlloss, c='orange', label="Validation")
ax[1].set_xlabel("Training step")
ax[1].set_ylabel("Loss")
ax[1].set_title("Loss (min on val: {:.2f})".format(min(vlloss)))
ax[1].legend()

# plt.tight_layout()
# plt.savefig('large_cnn.png', bbox_inches='tight')
plt.show()

# %%
########################################################################################

# %% [markdown]
# # HMF

# %%
htacc = np.load('Training Data/HMF/HMF-t-acc.npy')
htloss = np.load('Training Data/HMF/HMF-t-loss.npy')
hvacc = np.load('Training Data/HMF/HMF-v-acc.npy')
hvloss = np.load('Training Data/HMF/HMF-v-loss.npy')

# %%
print("LAST T-ACC:", htacc[-1], "MAX T-ACC:", max(htacc))
print("LAST V-ACC:", hvacc[-1], "MAX V-ACC:", max(hvacc))
# Out:
# LAST T-ACC: 1.0 MAX T-ACC: 1.0
# LAST V-ACC: 0.5722748809516147 MAX V-ACC: 0.598341233357434

# %%
fig, ax = plt.subplots(1,2, figsize=(20, 10))

# plt.suptitle("Large CNN Performance")
plt.rc('axes', titlesize=20) 
plt.rc('axes', labelsize=20)

ax[1].plot(htacc[:40], c='b', label="Training")
ax[1].plot(hvacc[:40], c='orange', label="Validation")
ax[1].axhline(.2, ls='--', c='r', label="Chance")
ax[1].set_xlabel("Training step")
ax[1].set_ylabel("Accuracy")
ax[1].set_title("Accuracy (max on val: {:.2f})".format(max(hvacc)))
ax[1].legend()

ax[0].plot(htloss, c='b', label="Training")
ax[0].plot(hvloss, c='orange', label="Validation")
ax[0].set_xlabel("Training step")
ax[0].set_ylabel("Loss")
ax[0].set_title("Loss (min on val: {:.2f})".format(min(hvloss)))
ax[0].legend()

# plt.tight_layout()
plt.savefig('HMF_cnn40.png', bbox_inches='tight')
plt.show()

# %%
htacc = np.load('Training Data/NEW/tL-acc.npy')
htloss = np.load('Training Data/NEW/tL-loss.npy')
hvacc = np.load('Training Data/NEW/vL-acc.npy')
hvloss = np.load('Training Data/NEW/vL-loss.npy')

print("LAST T-ACC:", htacc[-1], "MAX T-ACC:", max(htacc))
print("LAST V-ACC:", hvacc[-1], "MAX V-ACC:", max(hvacc))
# Out:
# LAST T-ACC: 0.20300157977883096 MAX T-ACC: 0.23854660347551343
# LAST V-ACC: 0.19431279627915243 MAX V-ACC: 0.24644549777157498

# %%
fig, ax = plt.subplots(1,2, figsize=(20, 10))

# plt.suptitle("Large CNN Performance")
plt.rc('axes', titlesize=20) 
plt.rc('axes', labelsize=20)

ax[0].plot(htacc[:200], c='b', label="Training")
ax[0].plot(hvacc[:200], c='orange', label="Validation")
ax[0].axhline(.2, ls='--', c='r', label="Chance")
ax[0].set_xlabel("Training step")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Accuracy (max on val: {:.2f})".format(max(hvacc)))
ax[0].legend()

ax[1].plot(htloss[:200], c='b', label="Training")
ax[1].plot(hvloss[:200], c='orange', label="Validation")
ax[1].set_xlabel("Training step")
ax[1].set_ylabel("Loss")
ax[1].set_title("Loss (min on val: {:.2f})".format(min(hvloss)))
ax[1].legend()

# plt.tight_layout()
# plt.savefig('large_cnn.png', bbox_inches='tight')
plt.show()
